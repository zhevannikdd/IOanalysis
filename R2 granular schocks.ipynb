# %%
import numpy as np
import pandas as pd

# %%
T16=np.loadtxt('data/T16.txt')
FD16=np.loadtxt('data/Eora26_2016_bp_FD.txt')
x16=np.sum(T16, axis= 1)+np.sum(FD16, axis=1)
T15=np.loadtxt('data/Eora26_2015_bp_T.txt')
FD15=np.loadtxt('data/Eora26_2015_bp_FD.txt')
x15=np.sum(T15, axis= 1)+np.sum(FD15, axis=1)
T14=np.loadtxt('data/Eora26_2014_bp_T.txt')
FD14=np.loadtxt('data/Eora26_2014_bp_FD.txt')
x14=np.sum(T14, axis= 1)+np.sum(FD14, axis=1)
T13=np.loadtxt('data/Eora26_2013_bp_T.txt')
FD13=np.loadtxt('data/Eora26_2013_bp_FD.txt')
x13=np.sum(T13, axis= 1)+np.sum(FD13, axis=1)
T12=np.loadtxt('data/Eora26_2012_bp_T.txt')
FD12=np.loadtxt('data/Eora26_2012_bp_FD.txt')
x12=np.sum(T12, axis= 1)+np.sum(FD12, axis=1)
T11=np.loadtxt('data/Eora26_2011_bp_T.txt')
FD11=np.loadtxt('data/Eora26_2011_bp_FD.txt')
x11=np.sum(T11, axis= 1)+np.sum(FD11, axis=1)
T10=np.loadtxt('data/Eora26_2010_bp_T.txt')
FD10=np.loadtxt('data/Eora26_2010_bp_FD.txt')
x10=np.sum(T10, axis= 1)+np.sum(FD10, axis=1)
T09=np.loadtxt('data/Eora26_2009_bp_T.txt')
FD09=np.loadtxt('data/Eora26_2009_bp_FD.txt')
x09=np.sum(T09, axis= 1)+np.sum(FD09, axis=1)
T08=np.loadtxt('data/Eora26_2008_bp_T.txt')
FD08=np.loadtxt('data/Eora26_2008_bp_FD.txt')
x08=np.sum(T08, axis= 1)+np.sum(FD08, axis=1)
T07=np.loadtxt('data/Eora26_2007_bp_T.txt')
FD07=np.loadtxt('data/Eora26_2007_bp_FD.txt')
x07=np.sum(T07, axis= 1)+np.sum(FD07, axis=1)
T06=np.loadtxt('data/Eora26_2006_bp_T.txt')
FD06=np.loadtxt('data/Eora26_2006_bp_FD.txt')
x06=np.sum(T06, axis= 1)+np.sum(FD06, axis=1)
T05=np.loadtxt('data/Eora26_2005_bp_T.txt')
FD05=np.loadtxt('data/Eora26_2005_bp_FD.txt')
x05=np.sum(T05, axis= 1)+np.sum(FD05, axis=1)
T04=np.loadtxt('data/Eora26_2004_bp_T.txt')
FD04=np.loadtxt('data/Eora26_2004_bp_FD.txt')
x04=np.sum(T04, axis= 1)+np.sum(FD04, axis=1)
T04=np.loadtxt('data/Eora26_2004_bp_T.txt')
FD04=np.loadtxt('data/Eora26_2004_bp_FD.txt')
x04=np.sum(T04, axis= 1)+np.sum(FD04, axis=1)
T03=np.loadtxt('data/Eora26_2003_bp_T.txt')
FD03=np.loadtxt('data/Eora26_2003_bp_FD.txt')
x03=np.sum(T03, axis= 1)+np.sum(FD03, axis=1)
T02=np.loadtxt('data/Eora26_2002_bp_T.txt')
FD02=np.loadtxt('data/Eora26_2002_bp_FD.txt')
x02=np.sum(T02, axis= 1)+np.sum(FD02, axis=1)
T01=np.loadtxt('data/Eora26_2001_bp_T.txt')
FD01=np.loadtxt('data/Eora26_2001_bp_FD.txt')
x01=np.sum(T01, axis= 1)+np.sum(FD01, axis=1)
T00=np.loadtxt('data/Eora26_2000_bp_T.txt')
FD00=np.loadtxt('data/Eora26_2000_bp_FD.txt')
x00=np.sum(T00, axis= 1)+np.sum(FD00, axis=1)
T99=np.loadtxt('data/Eora26_1999_bp_T.txt')
FD99=np.loadtxt('data/Eora26_1999_bp_FD.txt')
x99=np.sum(T99, axis= 1)+np.sum(FD99, axis=1)
T98=np.loadtxt('data/Eora26_1998_bp_T.txt')
FD98=np.loadtxt('data/Eora26_1998_bp_FD.txt')
x98=np.sum(T98, axis= 1)+np.sum(FD98, axis=1)
T97=np.loadtxt('data/Eora26_1997_bp_T.txt')
FD97=np.loadtxt('data/Eora26_1997_bp_FD.txt')
x97=np.sum(T97, axis= 1)+np.sum(FD97, axis=1)
T96=np.loadtxt('data/Eora26_1996_bp_T.txt')
FD96=np.loadtxt('data/Eora26_1996_bp_FD.txt')
x96=np.sum(T96, axis= 1)+np.sum(FD96, axis=1)
T95=np.loadtxt('data/Eora26_1995_bp_T.txt')
FD95=np.loadtxt('data/Eora26_1995_bp_FD.txt')
x95=np.sum(T95, axis= 1)+np.sum(FD95, axis=1)
T94=np.loadtxt('data/Eora26_1994_bp_T.txt')
FD94=np.loadtxt('data/Eora26_1994_bp_FD.txt')
x94=np.sum(T94, axis= 1)+np.sum(FD94, axis=1)
T93=np.loadtxt('data/Eora26_1993_bp_T.txt')
FD93=np.loadtxt('data/Eora26_1993_bp_FD.txt')
x93=np.sum(T93, axis= 1)+np.sum(FD93, axis=1)
T92=np.loadtxt('data/Eora26_1992_bp_T.txt')
FD92=np.loadtxt('data/Eora26_1992_bp_FD.txt')
x92=np.sum(T92, axis= 1)+np.sum(FD92, axis=1)
T91=np.loadtxt('data/Eora26_1991_bp_T.txt')
FD91=np.loadtxt('data/Eora26_1991_bp_FD.txt')
x91=np.sum(T91, axis= 1)+np.sum(FD91, axis=1)
T90=np.loadtxt('data/Eora26_1990_bp_T.txt')
FD90=np.loadtxt('data/Eora26_1990_bp_FD.txt')
x90=np.sum(T90, axis= 1)+np.sum(FD90, axis=1)

# %%
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x16*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy16=z1
w16=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x16*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy16=z1
w16=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x15*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy15=z1
w15=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x14*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy14=z1
w14=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x13*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy13=z1
w13=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x12*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy12=z1
w12=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x11*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy11=z1
w11=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x10*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy10=z1
w10=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x09*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy09=z1
w09=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x08*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy08=z1
w08=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x07*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy07=z1
w07=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x06*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy06=z1
w06=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x05*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy05=z1
w05=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x04*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy04=z1
w04=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x03*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy03=z1
w03=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x02*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy02=z1
w02=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x01*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy01=z1
w01=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x00*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy00=z1
w00=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x99*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy99=z1
w99=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x98*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy98=z1
w98=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x97*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy97=z1
w97=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x96*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy96=z1
w96=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x95*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy95=z1
w95=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x94*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy94=z1
w94=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x93*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy93=z1
w93=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x92*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy92=z1
w92=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x91*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy91=z1
w91=zi
lx=np.arange(len(x16))
z=np.zeros(len(x16))
zi=np.zeros(190)
z1=np.zeros(len(x16))
for i in range (190):
    z=np.zeros(len(x16))
    p=np.logical_and(lx>=0+i*26, lx<26+i*26 )
    a1=x90*p
    sume=np.sum(a1)
    zi[i]=sume
    z[0+i*26:26+i*26:1]=sume
    z1=z1+z
xy90=z1
w90=zi

# %%
x90=np.delete(x90, 3599)
x91=np.delete(x91, 3599)
x92=np.delete(x92, 3599)
x93=np.delete(x93, 3599)
x94=np.delete(x94, 3599)
x95=np.delete(x95, 3599)
x96=np.delete(x96, 3599)
x97=np.delete(x97, 3599)
x98=np.delete(x98, 3599)
x99=np.delete(x99, 3599)
x00=np.delete(x00, 3599)
x01=np.delete(x01, 3599)
x02=np.delete(x02, 3599)
x03=np.delete(x03, 3599)
x04=np.delete(x04, 3599)
x05=np.delete(x05, 3599)
x06=np.delete(x06, 3599)
x07=np.delete(x07, 3599)
x08=np.delete(x08, 3599)
x09=np.delete(x09, 3599)
x10=np.delete(x10, 3599)
x11=np.delete(x11, 3599)
x12=np.delete(x12, 3599)
x13=np.delete(x13, 3599)
x14=np.delete(x14, 3599)
x15=np.delete(x15, 3599)
x16=np.delete(x16, 3599)
x90=np.delete(x90, 2663)
x91=np.delete(x91, 2663)
x92=np.delete(x92, 2663)
x93=np.delete(x93, 2663)
x94=np.delete(x94, 2663)
x95=np.delete(x95, 2663)
x96=np.delete(x96, 2663)
x97=np.delete(x97, 2663)
x98=np.delete(x98, 2663)
x99=np.delete(x99, 2663)
x00=np.delete(x00, 2663)
x01=np.delete(x01, 2663)
x02=np.delete(x02, 2663)
x03=np.delete(x03, 2663)
x04=np.delete(x04, 2663)
x05=np.delete(x05, 2663)
x06=np.delete(x06, 2663)
x07=np.delete(x07, 2663)
x08=np.delete(x08, 2663)
x09=np.delete(x09, 2663)
x10=np.delete(x10, 2663)
x11=np.delete(x11, 2663)
x12=np.delete(x12, 2663)
x13=np.delete(x13, 2663)
x14=np.delete(x14, 2663)
x15=np.delete(x15, 2663)
x16=np.delete(x16, 2663)
xy90=np.delete(xy90, 3599)
xy91=np.delete(xy91, 3599)
xy92=np.delete(xy92, 3599)
xy93=np.delete(xy93, 3599)
xy94=np.delete(xy94, 3599)
xy95=np.delete(xy95, 3599)
xy96=np.delete(xy96, 3599)
xy97=np.delete(xy97, 3599)
xy98=np.delete(xy98, 3599)
xy99=np.delete(xy99, 3599)
xy00=np.delete(xy00, 3599)
xy01=np.delete(xy01, 3599)
xy02=np.delete(xy02, 3599)
xy03=np.delete(xy03, 3599)
xy04=np.delete(xy04, 3599)
xy05=np.delete(xy05, 3599)
xy06=np.delete(xy06, 3599)
xy07=np.delete(xy07, 3599)
xy08=np.delete(xy08, 3599)
xy09=np.delete(xy09, 3599)
xy10=np.delete(xy10, 3599)
xy11=np.delete(xy11, 3599)
xy12=np.delete(xy12, 3599)
xy13=np.delete(xy13, 3599)
xy14=np.delete(xy14, 3599)
xy15=np.delete(xy15, 3599)
xy16=np.delete(xy16, 3599)
xy90=np.delete(xy90, 2663)
xy91=np.delete(xy91, 2663)
xy92=np.delete(xy92, 2663)
xy93=np.delete(xy93, 2663)
xy94=np.delete(xy94, 2663)
xy95=np.delete(xy95, 2663)
xy96=np.delete(xy96, 2663)
xy97=np.delete(xy97, 2663)
xy98=np.delete(xy98, 2663)
xy99=np.delete(xy99, 2663)
xy00=np.delete(xy00, 2663)
xy01=np.delete(xy01, 2663)
xy02=np.delete(xy02, 2663)
xy03=np.delete(xy03, 2663)
xy04=np.delete(xy04, 2663)
xy05=np.delete(xy05, 2663)
xy06=np.delete(xy06, 2663)
xy07=np.delete(xy07, 2663)
xy08=np.delete(xy08, 2663)
xy09=np.delete(xy09, 2663)
xy10=np.delete(xy10, 2663)
xy11=np.delete(xy11, 2663)
xy12=np.delete(xy12, 2663)
xy13=np.delete(xy13, 2663)
xy14=np.delete(xy14, 2663)
xy15=np.delete(xy15, 2663)
xy16=np.delete(xy16, 2663)

# %%
y0=np.log(x91)-np.log(x90)
y1=np.log(x92)-np.log(x91)
y2=np.log(x93)-np.log(x92)
y3=np.log(x94)-np.log(x93)
y4=np.log(x95)-np.log(x94)
y5=np.log(x96)-np.log(x95)
y6=np.log(x97)-np.log(x96)
y7=np.log(x98)-np.log(x97)
y8=np.log(x99)-np.log(x98)
y9=np.log(x00)-np.log(x99)
y10=np.log(x01)-np.log(x00)
y11=np.log(x02)-np.log(x01)
y12=np.log(x03)-np.log(x02)
y13=np.log(x04)-np.log(x03)
y14=np.log(x05)-np.log(x04)
y15=np.log(x06)-np.log(x05)
y16=np.log(x07)-np.log(x06)
y17=np.log(x08)-np.log(x07)
y18=np.log(x09)-np.log(x08)
y19=np.log(x10)-np.log(x09)
y20=np.log(x11)-np.log(x10)
y21=np.log(x12)-np.log(x11)
y22=np.log(x13)-np.log(x12)
y23=np.log(x14)-np.log(x13)
y24=np.log(x15)-np.log(x14)
y25=np.log(x16)-np.log(x15)
b0=np.log(xy91)-np.log(xy90)
b1=np.log(xy92)-np.log(xy91)
b2=np.log(xy93)-np.log(xy92)
b3=np.log(xy94)-np.log(xy93)
b4=np.log(xy95)-np.log(xy94)
b5=np.log(xy96)-np.log(xy95)
b6=np.log(xy97)-np.log(xy96)
b7=np.log(xy98)-np.log(xy97)
b8=np.log(xy99)-np.log(xy99)
b9=np.log(xy00)-np.log(xy99)
b10=np.log(xy01)-np.log(xy00)
b11=np.log(xy02)-np.log(xy01)
b12=np.log(xy03)-np.log(xy02)
b13=np.log(xy04)-np.log(xy03)
b14=np.log(xy05)-np.log(xy04)
b15=np.log(xy06)-np.log(xy05)
b16=np.log(xy07)-np.log(xy06)
b17=np.log(xy08)-np.log(xy07)
b18=np.log(xy09)-np.log(xy08)
b19=np.log(xy10)-np.log(xy09)
b20=np.log(xy11)-np.log(xy10)
b21=np.log(xy12)-np.log(xy11)
b22=np.log(xy13)-np.log(xy12)
b23=np.log(xy14)-np.log(xy13)
b24=np.log(xy15)-np.log(xy14)
b25=np.log(xy16)-np.log(xy15)
yit=np.hstack((y0, y1, y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16,y17,y18,y19,y20,y21,y22,y23,y24,y25))
bit=np.hstack((b0, b1, b2,b3,b4,b5,b6,b7,b8,b9,b10,b11,b12,b13,b14,b15,b16,b17,b18,b19,b20,b21,b22,b23,b24,b25))
YI=np.hstack((x90, x91, x92,x93,x94,x95,x96,x97,x98,x99,x00,x01,x02,x03,x04,x05,x06,x07,x08,x09,x10,x11,x12,x13,x14,x15))

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression(fit_intercept = False)
lin_model.fit(bit.reshape(-1, 1), yit)
eit=yit-lin_model.predict(bit.reshape(-1, 1))

# %%
yiteit=YI*eit

# %%
lx=np.arange(len(YI))
z=np.zeros(len(YI))
z1=np.zeros(26)
for i in range (26):
    z=np.zeros(len(YI))
    p=np.logical_and(lx>=0+i*4914, lx<4914+i*4914 )
    a1=YI*p
    a2=yiteit*p
    sume1=np.sum(a1)
    sume2=np.sum(a2)
    g=(sume2/sume1)
    z1[i]=g
G=z1

# %%
y0=np.log(np.sum(x91))-np.log(np.sum(x90))
y1=np.log(np.sum(x92))-np.log(np.sum(x91))
y2=np.log(np.sum(x93))-np.log(np.sum(x92))
y3=np.log(np.sum(x94))-np.log(np.sum(x93))
y4=np.log(np.sum(x95))-np.log(np.sum(x94))
y5=np.log(np.sum(x96))-np.log(np.sum(x95))
y6=np.log(np.sum(x97))-np.log(np.sum(x96))
y7=np.log(np.sum(x98))-np.log(np.sum(x97))
y8=np.log(np.sum(x99))-np.log(np.sum(x98))
y9=np.log(np.sum(x00))-np.log(np.sum(x99))
y10=np.log(np.sum(x01))-np.log(np.sum(x00))
y11=np.log(np.sum(x02))-np.log(np.sum(x01))
y12=np.log(np.sum(x03))-np.log(np.sum(x02))
y13=np.log(np.sum(x04))-np.log(np.sum(x03))
y14=np.log(np.sum(x05))-np.log(np.sum(x04))
y15=np.log(np.sum(x06))-np.log(np.sum(x05))
y16=np.log(np.sum(x07))-np.log(np.sum(x06))
y17=np.log(np.sum(x08))-np.log(np.sum(x07))
y18=np.log(np.sum(x09))-np.log(np.sum(x08))
y19=np.log(np.sum(x10))-np.log(np.sum(x09))
y20=np.log(np.sum(x11))-np.log(np.sum(x10))
y21=np.log(np.sum(x12))-np.log(np.sum(x11))
y22=np.log(np.sum(x13))-np.log(np.sum(x12))
y23=np.log(np.sum(x14))-np.log(np.sum(x13))
y24=np.log(np.sum(x15))-np.log(np.sum(x14))
y25=np.log(np.sum(x16))-np.log(np.sum(x15))
yit=np.hstack((y0, y1, y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16,y17,y18,y19,y20,y21,y22,y23,y24,y25))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
